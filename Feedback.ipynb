# %% [markdown]
# <a href="https://colab.research.google.com/github/lg960214/DACON_Seoul_6/blob/develop/Feedback.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Test

# %%
# 서울생활이동_매뉴얼v3.pdf 도 첨부해주세요

# %% [markdown]
# # **시작 하기 전..**
#
#      이전 기획 설명에 대해 피드백을 받아 최종 주제를 선정하였습니다.
#      이번에는 구체적인 플로우를 보여드리고 미흡한 점이나 보강할 점등
#     세부 피드백을 한번 받아보고 싶습니다.
#
#
# ## **프로젝트 내용**
#      - 현행 문제점
#        노인 우대권을 통한 지하철 무임승차 급증으로 인한 서울시 부담 증가
#
#      - 해결 방향
#        노인 이동권을 제한하지 않으면서 서울시 부담을 줄일 수 있는 방법 제시
#
#      - 조사 주안점
#        현재 복지의 일환으로 우대권의 발급되고 있는데
#        교통취약계층인 노인층 모두에게 혜택이 고르게 분배되고 있는가?
#
# ## **분석을 위한 카테고리** // (계속 조사중)
#
#       1. 연령층.
#         일반적인 노인의 기준이자 우대권 발급 기준 연령 65세 이상의 남녀 대상.
#         5살씩 구간을 나눠 분류
#
#       2. 재산.
#         부유한 지역과 상대적으로 덜 부유한 지역으로 분류, 지역별 우대권 이용현황 분석.
#
#       3. 교통편의성.
#         지하철 역이나 버스정류장의 밀도 등의 지표로 대중교통접근성을 평가, 우대권 이용률과의 상관관계 조사.
#
#       4. 역 간 정보. 역 간 탑승자, 하차자, 이동경로 등의 분석
#
#       5. 목적지 정보.
#         공원, 노인시설, 지역상권 등 목적지의 시설 규모와 수를 파악해 많이 모이는 지역의 조건 분석
#
# ## **분석 목표**
#       1. 노인층 중에서도 취약계층(고연령, 교통편의성, 재산)들이 우대권을 적극적으로 사용하고 있는가?
#
#       2. 우대권 사용빈도수를 특정 소수집단이 독점하고 있는가?
#
#       3. 시설의 부족등의 원인으로 어쩔수없이 지하철을 이용하고 있는지 이용목적 파악
#
# ## **분석 방법 및 해결책**
#     - 분석방법
#       머신러닝 기법 이용
#       지하철로 많이 방문하는 지역과 그렇지 않은 지역으로 나누어 원인 피쳐 분석 (계속 논의중.)
#
#     - 해결책 제시
#       분석결과에 따라 결론은 달라지지만, 더 효율적인 '교통지원금 분배' 방식
#       혹은 교통지원이 아니라 시설확충등의 결론을 낼수 있도록 기대.
#
#
# ## **질문**
#
#      1. 유동인구 흐름과 시설, 인구 밀도 등 지도 시각화 자료가 많이 생산, 분석의 수단이 될것 같습니다.
#         이때 ML 방향을 결정할때 주실만한 조언을 받고싶습니다.
#
#      2. 다양한 출처의 연령별 인구 흐름 데이터를 활용해 분석의 정밀도를 올리고 싶은데,
#         이때 자료별 신뢰도를 개략적으로 추측할 수 있는 방법이 있을까요?
#
#      3. 위의 기획안에 대해 무엇이든 피드백 해주시면 감사하겠습니다.

# %% [markdown]
# ## **추가 질문**
#
# 1. Seaborn과 MatPlotLib 이외의 라이브러리의 사용법은 검색을 하면 나옵니다만, [서울생활이동 데이터 설명서](https://data.seoul.go.kr/dataVisual/seoul/seoulLivingMigration.do) 에서처럼 시각화하는 방법은 찾기 어려웠습니다. 해당 시각화 자료의 샘플이나 템플릿을 어디서 구할수 있을지 여쭤보고싶습니다.
# 2. 빅데이터 캠퍼스에 있는 데이터를 사용하고 싶은데 관련 질문입니다.
#   - 사용신청을하고 직접 방문을 해야만 사용할 수 있는건지? DB 서버관련 정보가 나와있던데 외부에서 접속 방법은 없는지.
#   - 만약 방문해야한다면 방문해서 데이터를 반출할 수 있는지
#   - 그것이 안된다면 캠퍼스 내에서 데이터를 이용해서 가공하고 분석한 결과는 반출 가능한 지?

# %% [markdown]
# ![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# 프로젝트 특징상 지도와 경계의 설정이 매우 중요합니다만 위 사진과 같이 오차가 제법 생겨 고민중입니다.
# 혹시 실전에서 서울시 구획간 경계나 영역 설정시 많이 쓰이는 지도-경계 셋이 별도로 있는지, 그리고 있다면 그 정보를 얻고 싶습니다.
