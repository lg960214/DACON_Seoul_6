# %%
import pandas as pd

# %%
df=pd.read_csv('G:/.shortcut-targets-by-id/1SPwJfApfbMnQhjtxLJc3Tnp7eAb9Zf5q/DACON6/서울시 시설 정보/서울시 경로당 정보.csv', encoding='cp949')
df.head()
# Out:
#      번호               사업장명                     소재지전체주소  도로명전체주소     인허가일자  \
# 0  3745       정릉꿈에그린(아)경로당       서울특별시 성북구 정릉동 정릉꿈에그린       NaN  20170808
# 1  3744       구파발10단 제3경로당     서울특별시 은평구 진관동 은평뉴타운구파발       NaN  20121212
# 2  3743        아현 아이파크 경로당         서울특별시 마포구 아현동 104동       NaN  20180406
# 3  3742  상암월드컵파크12단지(아)경로당  서울특별시 마포구 상암동 상암월드컵파크12단지       NaN  20110414
# 4  3741    상암월드컵파크11단지 경로당  서울특별시 마포구 상암동 상암월드컵파크11단지       NaN  20121024
#
#   영업상태명  폐업일자  휴업시작일자  휴업종료일자  재개업일자  소재지면적  소재지우편번호  입소정원  자격소유인원수  총인원수  \
# 0   운영중   NaN     NaN     NaN    NaN    NaN      NaN   NaN      NaN   NaN
# 1   운영중   NaN     NaN     NaN    NaN    NaN      NaN  22.0      NaN   NaN
# 2   운영중   NaN     NaN     NaN    NaN    NaN      NaN  23.0      NaN   NaN
# 3   운영중   NaN     NaN     NaN    NaN    NaN      NaN   NaN      NaN   NaN
# 4   운영중   NaN     NaN     NaN    NaN    NaN      NaN  36.0      NaN   NaN
#
#    위치정보(X)  위치정보(Y)             인허가번호 상세영업상태명
# ...

# %%
df = df[['사업장명','소재지전체주소']]

# %%
df.head()
# Out:
#                 사업장명                     소재지전체주소
# 0       정릉꿈에그린(아)경로당       서울특별시 성북구 정릉동 정릉꿈에그린
# 1       구파발10단 제3경로당     서울특별시 은평구 진관동 은평뉴타운구파발
# 2        아현 아이파크 경로당         서울특별시 마포구 아현동 104동
# 3  상암월드컵파크12단지(아)경로당  서울특별시 마포구 상암동 상암월드컵파크12단지
# 4    상암월드컵파크11단지 경로당  서울특별시 마포구 상암동 상암월드컵파크11단지

# %%
df=df.rename(columns={'소재지전체주소':'시설주소'})
df=df.rename(columns={'사업장명':'시설명'})

# %%
df.head()
df = df.dropna(axis=0)
df.to_csv('경로당.csv', index = False, encoding='utf-8-sig')

# %%
df2=pd.read_csv('G:/.shortcut-targets-by-id/1SPwJfApfbMnQhjtxLJc3Tnp7eAb9Zf5q/DACON6/서울시 시설 정보/서울시 사회복지시설(노인보호전문기관) 목록.csv', encoding='cp949')
df2.head()
# Out:
#                시설명    시설코드    시설종류명(시설유형) 시설종류상세명(시설종류) 자치구(시)구분 시설장명  \
# 0  서울특별시남부노인보호전문기관   A0533  (노인) 노인보호전문기관      노인보호전문기관      자치구  나경희
# 1       중앙노인보호전문기관   A1729  (노인) 노인보호전문기관      노인보호전문기관      자치구  최영숙
# 2  서울특별시북부노인보호전문기관   A6066  (노인) 노인보호전문기관      노인보호전문기관      자치구  민진홍
# 3      강원도노인보호전문기관  F04350  (노인) 노인보호전문기관      노인보호전문기관      자치구  한영미
# 4    서울시학대피해노인전용쉼터   G3727  (노인) 노인보호전문기관      노인보호전문기관      자치구  손세영
#
#         시군구코드   시군구명                                      시설주소
# 0  1165000000    서초구  서울특별시 서초구 남부순환로 2124까리따스종합복지관 (방배동)(방배동)
# 1  1156000000   영등포구           서울특별시 마포구 마포대로 182-10성촌빌딩 2층공덕동
# 2  1130500000    강북구              서울특별시 강북구 노해로 69대성빌딩 2층(수유동)
# 3  1165000000    서초구                                       NaN
# 4  1100000000  서울특별시          서울특별시 도봉구 도봉로108길 83-5 301호 (창동)

# %%
df2=df2[['시설명','시설주소']]
df2.head()
df2 = df2.dropna(axis=0)

df2.to_csv('노인보호전문기관.csv', index = False, encoding='utf-8-sig')

# %%
df3=pd.read_csv('G:/.shortcut-targets-by-id/1SPwJfApfbMnQhjtxLJc3Tnp7eAb9Zf5q/DACON6/서울시 시설 정보/서울시 사회복지시설(노인여가복지시설) 목록.csv', encoding='cp949')
df3.head()
# Out:
#               시설명   시설코드      시설종류명(시설유형) 시설종류상세명(시설종류) 자치구(시)구분  시설장명  \
# 0  성북구립 상월곡실버복지센터  A0495  (노인) 노인복지관(소규모)      노인여가복지시설      자치구   김경회
# 1   서초구립양재노인종합복지관  A0724       (노인) 노인복지관      노인여가복지시설      자치구  전경아
# 2   강서구립봉제산노인복지센터  A0922  (노인) 노인복지관(소규모)      노인여가복지시설      자치구   서순애
# 3     시립중랑노인종합복지관  A1022       (노인) 노인복지관      노인여가복지시설      자치구   조희정
# 4   강남구립강남노인종합복지관  A1165       (노인) 노인복지관      노인여가복지시설      자치구   고영한
#
#         시군구코드 시군구명                                   시설주소
# 0  1129000000  성북구              서울특별시 성북구 화랑로18길 6 (상월곡동)
# 1  1165000000  서초구  서울특별시 서초구 강남대로30길 73-7양재노인종합복지관 (양재동)
# 2  1150000000  강서구                  서울특별시 강서구 초록마을로15길 12
# 3  1126000000  중랑구                서울특별시 중랑구 겸재로9길 45(면목동)
# 4  1168000000  강남구       서울특별시 강남구 삼성로 628강남노인종합복지관 (삼성동)

# %%
df3=df3[['시설명','시설주소']]
df3.head()
df3 = df3.dropna(axis=0)
df3.to_csv('노인여가복지시설.csv', index = False, encoding='utf-8-sig')

# %%
df4=pd.read_csv('G:/.shortcut-targets-by-id/1SPwJfApfbMnQhjtxLJc3Tnp7eAb9Zf5q/DACON6/서울시 시설 정보/서울시 사회복지시설(노인의료복지시설) 목록.csv', encoding='cp949')
df4.head()
# Out:
#                 시설명   시설코드  시설종류명(시설유형) 시설종류상세명(시설종류) 자치구(시)구분 시설장명  \
# 0      서울꽃동네신내노인요양원  A0001  (노인) 노인요양시설      노인의료복지시설      자치구  최은숙
# 1           청운노인요양원  A0003  (노인) 노인요양시설      노인의료복지시설      자치구  이종후
# 2           천사노인요양원  A0007  (노인) 노인요양시설      노인의료복지시설      자치구  김샛별
# 3  서울특별시립 남부노인전문요양원  A0016  (노인) 노인요양시설      노인의료복지시설      자치구  한철수
# 4       노인요양센터 인영실버  A0099  (노인) 노인요양시설      노인의료복지시설      자치구  이희법
#
#         시군구코드  시군구명                     시설주소
# 0  1126000000   중랑구       서울특별시 중랑구 신내로 194
# 1  1111000000   종로구   서울특별시 종로구 비봉길 76 (구기동)
# 2  1150000000   강서구  서울특별시 강서구 강서로45다길 30-22
# 3  1156000000  영등포구          경기도 군포시 고산로 589
# 4  1154500000   금천구     서울특별시 금천구 금하로 596-0

# %%
df4=df4[['시설명','시설주소']]
df4.head()
df4 = df4.dropna(axis=0)
df4.to_csv('노인의료복지시설.csv', index = False, encoding='utf-8-sig')

# %%
df5=pd.read_csv('G:/.shortcut-targets-by-id/1SPwJfApfbMnQhjtxLJc3Tnp7eAb9Zf5q/DACON6/서울시 시설 정보/서울시 사회복지시설(노인주거복지시설) 목록.csv', encoding='cp949')
df5.head()
# Out:
#        시설명   시설코드 시설종류명(시설유형) 시설종류상세명(시설종류) 자치구(시)구분 시설장명       시군구코드  시군구명  \
# 0    청운양로원  A0002   (노인) 양로시설      노인주거복지시설      자치구  이종명  1111000000   종로구
# 1    홍파양로원  A0004   (노인) 양로시설      노인주거복지시설      자치구  김우리  1135000000   노원구
# 2    혜명양로원  A0019   (노인) 양로시설      노인주거복지시설      자치구  채명석  1154500000   금천구
# 3  시립고덕양로원  A0098   (노인) 양로시설      노인주거복지시설      자치구  박기아  1174000000   강동구
# 4    서울성모원  A2156   (노인) 양로시설      노인주거복지시설      자치구  오양식  1156000000  영등포구
#
#                          시설주소
# 0      서울특별시 종로구 비봉길 76 (구기동)
# 1  서울특별시 노원구 동일로248길 30 (상계동)
# 2    서울특별시 금천구 금하로29길 36(시흥동)
# 3      서울특별시 강동구 고덕로 199(고덕동)
# 4      서울특별시 영등포구 대림로12가길 7-1

# %%
df5=df5[['시설명','시설주소']]
df5.head()
df5 = df5.dropna(axis=0)
df5.to_csv('노인주거복지시설.csv', index = False, encoding='utf-8-sig')

# %%
df6=pd.read_csv('G:/.shortcut-targets-by-id/1SPwJfApfbMnQhjtxLJc3Tnp7eAb9Zf5q/DACON6/서울시 시설 정보/서울시 사회복지시설(재가노인복지시설) 목록.csv', encoding='cp949')
df6.head()
# Out:
#                    시설명   시설코드    시설종류명(시설유형) 시설종류상세명(시설종류) 자치구(시)구분 시설장명  \
# 0            참사랑데이케어센터  A0166  (노인) 재가노인복지시설      재가노인복지시설      자치구  최신영
# 1         우리사랑재가노인지원센터  A0564  (노인) 재가노인복지시설      재가노인복지시설      자치구  정춘선
# 2          동대문실버데이케어센터  A0638  (노인) 재가노인복지시설      재가노인복지시설      자치구  이동수
# 3          한국씨니어노인복지센터  A0681  (노인) 재가노인복지시설      재가노인복지시설      자치구  반명규
# 4  목동종합사회복지관병설목동노인복지센터  A0707  (노인) 재가노인복지시설      재가노인복지시설      자치구  유영덕
#
#         시군구코드   시군구명                                시설주소
# 0  1171000000    송파구                    서울특별시 송파구 마천로 89
# 1  1123000000   동대문구           서울특별시 동대문구 휘경로12길 83(휘경동)
# 2  1100000000  서울특별시  서울특별시 동대문구 약령시로5길 223층 동대문실버데이케어센터
# 3  1159000000    동작구                서울특별시 동작구 상도로30길 82층
# 4  1147000000    양천구  서울특별시 양천구 목동중앙북로8길 104목동종합사회복지관 2층

# %%
df6=df6[['시설명','시설주소']]
df6.head()
df6 = df6.dropna(axis=0)
df6.to_csv('재가노인복지시설.csv', index = False, encoding='utf-8-sig')
